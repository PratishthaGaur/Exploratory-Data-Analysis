# %% [markdown]
# <a href="https://colab.research.google.com/github/PratishthaGaur/Exploratory-Data-Analysis/blob/main/Italy_Covid19_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv(r"/content/drive/MyDrive/national_data.csv")

# %%
data.head()
# Out:
#                   data  deceduti  ...  totale_positivi  variazione_totale_positivi
# 0  2020-02-24T18:00:00         7  ...              221                           0
# 1  2020-02-25T18:00:00        10  ...              311                          90
# 2  2020-02-26T18:00:00        12  ...              385                          74
# 3  2020-02-27T18:00:00        17  ...              588                         203
# 4  2020-02-28T18:00:00        21  ...              821                         233
#
# [5 rows x 15 columns]

# %%
data.tail()
# Out:
#                    data  deceduti  ...  totale_positivi  variazione_totale_positivi
# 32  2020-03-27T17:00:00      9134  ...            66414                        4401
# 33  2020-03-28T17:00:00     10023  ...            70065                        3651
# 34  2020-03-29T17:00:00     10779  ...            73880                        3815
# 35  2020-03-30T17:00:00     11591  ...            75528                        1648
# 36  2020-03-31T17:00:00     12428  ...            77635                        2107
#
# [5 rows x 15 columns]

# %%
data.columns
# Out:
# Index(['data', 'deceduti', 'dimessi_guariti', 'isolamento_domiciliare',
#        'note_en', 'note_it', 'nuovi_positivi', 'ricoverati_con_sintomi',
#        'stato', 'tamponi', 'terapia_intensiva', 'totale_casi',
#        'totale_ospedalizzati', 'totale_positivi',
#        'variazione_totale_positivi'],
#       dtype='object')

# %%
data.describe()
# Out:
#            deceduti  ...  variazione_totale_positivi
# count     37.000000  ...                   37.000000
# mean    3153.027027  ...                 2092.270270
# std     3865.486267  ...                 1601.052825
# min        7.000000  ...                    0.000000
# 25%      107.000000  ...                  528.000000
# 50%     1266.000000  ...                 2107.000000
# 75%     5476.000000  ...                 3612.000000
# max    12428.000000  ...                 4821.000000
#
# [8 rows x 11 columns]

# %%
#Check null values
data.isnull().sum()
# Out:
# data                           0
# deceduti                       0
# dimessi_guariti                0
# isolamento_domiciliare         0
# note_en                       29
# note_it                       29
# nuovi_positivi                 0
# ricoverati_con_sintomi         0
# stato                          0
# tamponi                        0
# terapia_intensiva              0
# totale_casi                    0
# totale_ospedalizzati           0
# totale_positivi                0
# variazione_totale_positivi     0
# dtype: int64

# %% [markdown]
# Scatterplot description

# %%
sns.relplot(x="totale_casi",y="ricoverati_con_sintomi",data=data)

# %%
sns.relplot(x="totale_casi",y="deceduti",data=data)

# %%
sns.relplot(x="totale_casi",y="totale_ospedalizzati",data=data)
#Every 1 of 3 people are hospitalized with symptoms

# %%
sns.pairplot(data=data)
#For every possible pair

# %%
sns.catplot(x="ricoverati_con_sintomi",y="totale_casi",data=data)
